# %%
# Import libraries and packages for the project 

# from selenium import webdriver
# from selenium.webdriver.common.keys import Keys
# from bs4 import BeautifulSoup
# from time import sleep
# import csv

import requests
from time import sleep
import random
import pandas as pd
import re

print('- Finish importing packages')
# Out:
# - Finish importing packages

# %%
# driver  = webdriver.Edge("C:/Users/ASUS/Desktop/installer/msedgedriver.exe")
# sleep(2)
# url = 'https://www.foody.vn/'
# driver.get(url)
# print('- Finish initializing a driver')
# sleep(2)

# %%
cookies_str = 'TOKENS={"access_token":"ZRnJeouAkBi2qOVvx3zy0dIhgNb9l7EX"}; _trackity=4fa7fd37-7023-4960-a6fb-39a614221ab9; _gac_UA-15036050-1=1.1658929562.Cj0KCQjwxIOXBhCrARIsAL1QFCaSjOJzePTfL9t_7v9krIuYGU2rPfIjf4FFkCsYkOPj-jTp0_Nh27kaArsREALw_wcB; _gcl_aw=GCL.1658929562.Cj0KCQjwxIOXBhCrARIsAL1QFCaSjOJzePTfL9t_7v9krIuYGU2rPfIjf4FFkCsYkOPj-jTp0_Nh27kaArsREALw_wcB; _gcl_au=1.1.1374204249.1658929562; _ym_d=1658929564; _ym_uid=16589295641057945933; _fbp=fb.1.1658929564647.1681658300; _hjid=91c95007-af03-4fa0-996e-3129912be634; _hjSessionUser_522327=eyJpZCI6ImRlMjI0ZTMxLTk3ZGQtNTU4MC05NjU3LTI5Mzk2ZjEzNzIxOCIsImNyZWF0ZWQiOjE2NTg5Mjk1NjU1NzMsImV4aXN0aW5nIjp0cnVlfQ==; __RC=5; __utm=source=google|medium=cpc|campaign=SEA_NBR_GGL_TXT_SBR_ALL_VN_ALL_UNK_UNK_C.ALL_X.7602151122_Y.80058006606_Q.e_K.Tiki_W.DT_R.392788512410_T.kwd-10246492_L.HP_O.CAC; __utm=source=google|medium=cpc|campaign=SEA_NBR_GGL_TXT_SBR_ALL_VN_ALL_UNK_UNK_C.ALL_X.7602151122_Y.80058006606_Q.e_K.Tiki_W.DT_R.392788512410_T.kwd-10246492_L.HP_O.CAC; __iid=749; __iid=749; __su=0; __su=0; __R=3; __tb=0; amp_99d374_tiki.vn=X--hfPXDz1JEaZMhWPMV82...1g943a7mn.1g943am4t.i.u.1g; TKSESSID=836ec0e7600b62d0a6699c96327e0b2b; delivery_zone=Vk4wMzkwMDYwMDE=; _gid=GA1.2.4912776.1660486495; tiki_client_id=1961782734.1658929562; _hjSession_522327=eyJpZCI6Ijg0NGFkNmE1LTYzZmEtNDc1OC1iMzU1LTBkNTI5NDNiNzUxNCIsImNyZWF0ZWQiOjE2NjA0ODY1MDAwNTYsImluU2FtcGxlIjpmYWxzZX0=; _hjAbsoluteSessionInProgress=0; _ym_isad=2; __IP=20255071; _ga=GA1.1.1961782734.1658929562; __uif=__uid:436048649920255071|__ui:-1|__create:1660486499; cto_bundle=oFv51l9MMkQ1NlVpTVZjbUhlNlZkVlkwJTJCMjZqMGtpWHBQWlduZ0hpOExUNjBMenJ2Z1glMkZlQWdhOEt4SzdiTVpsSFdSQzJIS1ZVZlNVc2w1OGpqMXh1aDA1eER6Y3lRVHdKbnVyazJ5MzN6RzJwV3JFR1RSQlFWaWUyWUZQSXV6bUJValY; amp_99d374=X--hfPXDz1JEaZMhWPMV82...1gaee233m.1gaee2ktg.29.37.5g; _ga_GSD4ETCY1D=GS1.1.1660489630.9.0.1660489630.60'
cookies_list = cookies_str.split('; ')
cookies = dict(s.split('=',1) for s in cookies_list)
cookies['TOKENS'] = re.sub('[{}]', '', cookies['TOKENS'])
cookies
# Out:
# {'TOKENS': '"access_token":"ZRnJeouAkBi2qOVvx3zy0dIhgNb9l7EX"',
#  '_trackity': '4fa7fd37-7023-4960-a6fb-39a614221ab9',
#  '_gac_UA-15036050-1': '1.1658929562.Cj0KCQjwxIOXBhCrARIsAL1QFCaSjOJzePTfL9t_7v9krIuYGU2rPfIjf4FFkCsYkOPj-jTp0_Nh27kaArsREALw_wcB',
#  '_gcl_aw': 'GCL.1658929562.Cj0KCQjwxIOXBhCrARIsAL1QFCaSjOJzePTfL9t_7v9krIuYGU2rPfIjf4FFkCsYkOPj-jTp0_Nh27kaArsREALw_wcB',
#  '_gcl_au': '1.1.1374204249.1658929562',
#  '_ym_d': '1658929564',
#  '_ym_uid': '16589295641057945933',
#  '_fbp': 'fb.1.1658929564647.1681658300',
#  '_hjid': '91c95007-af03-4fa0-996e-3129912be634',
#  '_hjSessionUser_522327': 'eyJpZCI6ImRlMjI0ZTMxLTk3ZGQtNTU4MC05NjU3LTI5Mzk2ZjEzNzIxOCIsImNyZWF0ZWQiOjE2NTg5Mjk1NjU1NzMsImV4aXN0aW5nIjp0cnVlfQ==',
#  '__RC': '5',
#  '__utm': 'source=google|medium=cpc|campaign=SEA_NBR_GGL_TXT_SBR_ALL_VN_ALL_UNK_UNK_C.ALL_X.7602151122_Y.80058006606_Q.e_K.Tiki_W.DT_R.392788512410_T.kwd-10246492_L.HP_O.CAC',
#  '__iid': '749',
#  '__su': '0',
#  '__R': '3',
#  '__tb': '0',
# ...

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.5112.81 Safari/537.36 Edg/104.0.1293.54',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9,vi;q=0.8',
    'Referer': 'https://tiki.vn/dien-tu-dien-lanh/c4221',
    'x-guest-token': 'ZRnJeouAkBi2qOVvx3zy0dIhgNb9l7EX',
    'TE': 'Trailers'
}

# %%
params = {
    'limit': '48',
    'include': 'advertisement',
    'aggregations': '2',
    'trackity_id': '4fa7fd37-7023-4960-a6fb-39a614221ab9',
    'category': '4221',
    'page': '1',
    'src': 'c4221',
    'urlKey': 'dien-tu-dien-lanh',
}

# %%
params['page']=20
response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers, params=params)
1 if response.json().get('data') else 0
# Out:
# 0

# %%
product_ids = []
for i  in range(1,100): 
    params['page'] = i
    response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers, params=params)
    if response.status_code == 200:
        if response.json().get('data'):
            print('Crawl page {}'.format(i))
            for record in response.json().get('data'):
                product_ids.append({'id': record.get('id')})
        else:
            break
    
product_ids
# Out:
# Crawl page 1
# Crawl page 2
# Crawl page 3
# Crawl page 4
# Crawl page 5
# Crawl page 6
# Crawl page 7
# Crawl page 8
# Crawl page 9
# Crawl page 10
# Crawl page 11
# Crawl page 12
# Crawl page 13
# Crawl page 14
# Crawl page 15
# Crawl page 16
# Crawl page 17
# Crawl page 18
# Crawl page 19
# Crawl page 20
# Crawl page 21
# Crawl page 22
# Crawl page 23
# Crawl page 24
# Crawl page 25
# Crawl page 26
# Crawl page 27
# Crawl page 28
# Crawl page 29
# Crawl page 30
# Crawl page 31
# Crawl page 32
# Crawl page 33
# Crawl page 34
# Crawl page 35
# Crawl page 36
# Crawl page 37
# Crawl page 38
# Crawl page 39
# Crawl page 40
# Crawl page 41
# Crawl page 42
# [{'id': 108175089},
#  {'id': 845378},
#  {'id': 87161397},
#  {'id': 95513168},
#  {'id': 110791834},
#  {'id': 54763799},
#  {'id': 72748642},
#  {'id': 845378},
#  {'id': 72748653},
#  {'id': 55596971},
#  {'id': 16931128},
#  {'id': 50560441},
#  {'id': 144070572},
#  {'id': 47126547},
#  {'id': 53751834},
#  {'id': 7749111},
# ...

# %%
df = pd.DataFrame(product_ids)
df.to_csv('productID_dtdl.csv',index=False)
